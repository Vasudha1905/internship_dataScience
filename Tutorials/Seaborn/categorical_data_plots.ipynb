# %% [markdown]
# ## Categorical Data Plots
# * swarmplot() and stripplot() that show each observation at each level of the categorical variable.
# * boxplot() and violinplot() that show an abstract representation of each distribution of observations.
# * barplot(), pointplot() and countplot() that apply a statistical estimation to show a measure of Central Tendency and Confidence Interval
# * fatorplot() is the most general form of a categorical plot. It can take in a kind parameter to adjust the plot type.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
# %matplotlib inline
# warnings.filterwarnings("ignore")
sns.set(rc={"figure.figsize": (5, 3)})
sns.set_style('whitegrid')

# %% [markdown]
# ### swarm plot
# This plot is a scattered representation of non-overlapping points of the three species of Iris flower with difference in values of their sepal length, sepal width, petal length and petal width.

# %%
# loading dataset
iris=sns.load_dataset('iris')
# Melt dataset to 'long-form' or 'tidy' representation:
iris = pd.melt(iris, "species", var_name="measurement")

# %%
# Drawing a categorical scatterplot to show each observation
sns.swarmplot(x="measurement", y="value", hue="species", data=iris,palette='deep')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# changing order

# %%
sns.swarmplot(x="measurement", y="value", hue="species", data=iris,order=['sepal_width','petal_width','sepal_length','petal_length'],palette='viridis')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 46.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### strip plot
# * It displays the distribution of a continuous variable for each category by placing individual data points along a axis.

# %%
tips = sns.load_dataset("tips")
sns.stripplot(x=tips["total_bill"], size=4, color="green")
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips,palette='rocket')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\Temp\ipykernel_26620\1166698457.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x="day", y="total_bill", data=tips,palette='rocket')
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex', palette='Set1')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# split the dots by category

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex', palette='Set1', dodge=True)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
iris = sns.load_dataset("iris")
iris = pd.melt(iris, "species", var_name="measurement")
sns.stripplot(x="measurement", y="value", hue="species",data=iris, palette="icefire", size=15,marker='p', alpha=.20)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='measurement', ylabel='value'>

# %% [markdown]
# ### box plot()
# depicts group of numerical data through their quartiles in Descriptive statistics

# %%
# Plotting basic Box Plot:
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette='viridis')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# box plot and stripplot together

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='Set3')
sns.stripplot(x="day", y="total_bill", data=tips, color='b')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### violin plot
# it combines boxplot and kde

# %%
# Plotting basic Violin Plot horizontally:
sns.violinplot(x = tips["total_bill"], palette="coolwarm")
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# * thick bar in the centre is the interquartile range
# * the thin line represents the confidence interval
# * the white dot is median
# * the spread forms the violin shape is kde which shows distribution- wider means higher probability

# %%
# Loading built-in Tips dataset:
tips = sns.load_dataset("tips")
# Draw a vertical violinplot grouped by a categorical variable:
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Draw split violins to compare the across the hue variable:
sns.violinplot(x='day', y='total_bill', hue='sex', data = tips, palette='muted', split=True)
plt.legend()
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# scale on basis of count

# %%
# Scale the violin width by the number of observations in each bin:
sns.violinplot(x ='day', y='total_bill', hue='sex', data = tips, palette='muted', split=True,scale = 'count' )
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# drawing quartiles

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, inner='quartile')
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# reduce bandwidth to reduce smoothning

# %%
sns.violinplot(x="day", y="total_bill",data=tips, bw=.2)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Bar Plot

# %%
# Loading built-in Tips dataset:
titanic = sns.load_dataset("titanic")
sns.barplot(x="class", y="fare", data=titanic)
# the lines repesent confidence interval
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# adding standard deviation

# %%
sns.barplot(x="embark_town", y="age", data=titanic, hue="sex", errorbar="sd",capsize=0.3)
# Out:
# <Axes: xlabel='embark_town', ylabel='age'>

# %% [markdown]
# ### count plot
# A Count Plot can be thought of as a Histogram across a Categorical variable, instead of a Quantitative variable.

# %%
sns.countplot(x='class', data=titanic)
# Out:
# C:\Users\Vasudharajesh.i\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ### point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of the dot and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic, palette="rocket")
# Out:
# <Axes: xlabel='sex', ylabel='survived'>
